# %%
from gurobipy import Model, GRB

# %%
s_1 = Model("schedule for IE freshmen in fall semester")
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-03

# %%
# 각 수업의 수강 여부 변수

X_1= s_1.addVar(vtype=GRB.BINARY, name = "1th_class")
X_2= s_1.addVar(vtype=GRB.BINARY, name = "2th_class")
X_3= s_1.addVar(vtype=GRB.BINARY, name = "3th_class")
X_4= s_1.addVar(vtype=GRB.BINARY, name = "4th_class")
X_5= s_1.addVar(vtype=GRB.BINARY, name = "5th_class")
X_6= s_1.addVar(vtype=GRB.BINARY, name = "6th_class")
X_7= s_1.addVar(vtype=GRB.BINARY, name = "7th_class")
X_8= s_1.addVar(vtype=GRB.BINARY, name = "8th_class")
X_9= s_1.addVar(vtype=GRB.BINARY, name = "9th_class")
X_10= s_1.addVar(vtype=GRB.BINARY, name = "10th_class")
X_11= s_1.addVar(vtype=GRB.BINARY, name = "11th_class")
X_12= s_1.addVar(vtype=GRB.BINARY, name = "12th_class")
X_13= s_1.addVar(vtype=GRB.BINARY, name = "13th_class")
X_14= s_1.addVar(vtype=GRB.BINARY, name = "14th_class")
X_15= s_1.addVar(vtype=GRB.BINARY, name = "15th_class")
X_16= s_1.addVar(vtype=GRB.BINARY, name = "16th_class")
X_17= s_1.addVar(vtype=GRB.BINARY, name = "17th_class")
X_18= s_1.addVar(vtype=GRB.BINARY, name = "18th_class")
X_19= s_1.addVar(vtype=GRB.BINARY, name = "19th_class")
X_20= s_1.addVar(vtype=GRB.BINARY, name = "20th_class")
X_21= s_1.addVar(vtype=GRB.BINARY, name = "21th_class")
X_22= s_1.addVar(vtype=GRB.BINARY, name = "22th_class")
X_23= s_1.addVar(vtype=GRB.BINARY, name = "23th_class")
X_24= s_1.addVar(vtype=GRB.BINARY, name = "24th_class")
X_25= s_1.addVar(vtype=GRB.BINARY, name = "25th_class")
X_26= s_1.addVar(vtype=GRB.BINARY, name = "26th_class")
X_27= s_1.addVar(vtype=GRB.BINARY, name = "27th_class")
X_28= s_1.addVar(vtype=GRB.BINARY, name = "28th_class")
X_29= s_1.addVar(vtype=GRB.BINARY, name = "29th_class")
X_30= s_1.addVar(vtype=GRB.BINARY, name = "30th_class")
X_31= s_1.addVar(vtype=GRB.BINARY, name = "31th_class")
X_32= s_1.addVar(vtype=GRB.BINARY, name = "32th_class")
X_33= s_1.addVar(vtype=GRB.BINARY, name = "33th_class")
X_34= s_1.addVar(vtype=GRB.BINARY, name = "34th_class")
X_35= s_1.addVar(vtype=GRB.BINARY, name = "35th_class")
X_36= s_1.addVar(vtype=GRB.BINARY, name = "36th_class")
X_37= s_1.addVar(vtype=GRB.BINARY, name = "37th_class")
X_38= s_1.addVar(vtype=GRB.BINARY, name = "38th_class")
X_39= s_1.addVar(vtype=GRB.BINARY, name = "39th_class")
X_40= s_1.addVar(vtype=GRB.BINARY, name = "40th_class")
X_41= s_1.addVar(vtype=GRB.BINARY, name = "41th_class")
X_42= s_1.addVar(vtype=GRB.BINARY, name = "42th_class")
X_43= s_1.addVar(vtype=GRB.BINARY, name = "43th_class")
X_44= s_1.addVar(vtype=GRB.BINARY, name = "44th_class")
X_45= s_1.addVar(vtype=GRB.BINARY, name = "45th_class")
X_46= s_1.addVar(vtype=GRB.BINARY, name = "46th_class")
X_47= s_1.addVar(vtype=GRB.BINARY, name = "47th_class")
X_48= s_1.addVar(vtype=GRB.BINARY, name = "48th_class")
X_49= s_1.addVar(vtype=GRB.BINARY, name = "49th_class")
X_50= s_1.addVar(vtype=GRB.BINARY, name = "50th_class")
X_51= s_1.addVar(vtype=GRB.BINARY, name = "51th_class")
X_52= s_1.addVar(vtype=GRB.BINARY, name = "52th_class")
X_53= s_1.addVar(vtype=GRB.BINARY, name = "53th_class")
X_54= s_1.addVar(vtype=GRB.BINARY, name = "54th_class")
X_55= s_1.addVar(vtype=GRB.BINARY, name = "55th_class")
X_56= s_1.addVar(vtype=GRB.BINARY, name = "56th_class")
X_57= s_1.addVar(vtype=GRB.BINARY, name = "57th_class")
X_58= s_1.addVar(vtype=GRB.BINARY, name = "58th_class")
X_59= s_1.addVar(vtype=GRB.BINARY, name = "59th_class")
X_60= s_1.addVar(vtype=GRB.BINARY, name = "60th_class")
X_61= s_1.addVar(vtype=GRB.BINARY, name = "61th_class")
X_62= s_1.addVar(vtype=GRB.BINARY, name = "62th_class")
X_63= s_1.addVar(vtype=GRB.BINARY, name = "63th_class")
X_64= s_1.addVar(vtype=GRB.BINARY, name = "64th_class")
X_65= s_1.addVar(vtype=GRB.BINARY, name = "65th_class")
X_66= s_1.addVar(vtype=GRB.BINARY, name = "66th_class")
X_67= s_1.addVar(vtype=GRB.BINARY, name = "67th_class")
X_68= s_1.addVar(vtype=GRB.BINARY, name = "68th_class")
X_69= s_1.addVar(vtype=GRB.BINARY, name = "69th_class")
X_70= s_1.addVar(vtype=GRB.BINARY, name = "70th_class")
X_71= s_1.addVar(vtype=GRB.BINARY, name = "71th_class")
X_72= s_1.addVar(vtype=GRB.BINARY, name = "72th_class")
X_73= s_1.addVar(vtype=GRB.BINARY, name = "73th_class")
X_74= s_1.addVar(vtype=GRB.BINARY, name = "74th_class")
X_75= s_1.addVar(vtype=GRB.BINARY, name = "75th_class")
X_76= s_1.addVar(vtype=GRB.BINARY, name = "76th_class")
X_77= s_1.addVar(vtype=GRB.BINARY, name = "77th_class")
X_78= s_1.addVar(vtype=GRB.BINARY, name = "78th_class")
X_79= s_1.addVar(vtype=GRB.BINARY, name = "79th_class")
X_80= s_1.addVar(vtype=GRB.BINARY, name = "80th_class")
X_81= s_1.addVar(vtype=GRB.BINARY, name = "81th_class")
X_82= s_1.addVar(vtype=GRB.BINARY, name = "82th_class")
X_83= s_1.addVar(vtype=GRB.BINARY, name = "83th_class")
X_84= s_1.addVar(vtype=GRB.BINARY, name = "84th_class")
X_85= s_1.addVar(vtype=GRB.BINARY, name = "85th_class")
X_86= s_1.addVar(vtype=GRB.BINARY, name = "86th_class")
X_87= s_1.addVar(vtype=GRB.BINARY, name = "87th_class")
X_88= s_1.addVar(vtype=GRB.BINARY, name = "88th_class")
X_89= s_1.addVar(vtype=GRB.BINARY, name = "89th_class")
X_90= s_1.addVar(vtype=GRB.BINARY, name = "90th_class")
X_91= s_1.addVar(vtype=GRB.BINARY, name = "91th_class")
X_92= s_1.addVar(vtype=GRB.BINARY, name = "92th_class")
X_93= s_1.addVar(vtype=GRB.BINARY, name = "93th_class")
X_94= s_1.addVar(vtype=GRB.BINARY, name = "94th_class")
X_95= s_1.addVar(vtype=GRB.BINARY, name = "95th_class")
X_96= s_1.addVar(vtype=GRB.BINARY, name = "96th_class")
X_97= s_1.addVar(vtype=GRB.BINARY, name = "97th_class")
X_98= s_1.addVar(vtype=GRB.BINARY, name = "98th_class")
X_99= s_1.addVar(vtype=GRB.BINARY, name = "99th_class")
X_100= s_1.addVar(vtype=GRB.BINARY, name = "100th_class")
X_101= s_1.addVar(vtype=GRB.BINARY, name = "101th_class")
X_102= s_1.addVar(vtype=GRB.BINARY, name = "102th_class")
X_103= s_1.addVar(vtype=GRB.BINARY, name = "103th_class")
X_104= s_1.addVar(vtype=GRB.BINARY, name = "104th_class")
X_105= s_1.addVar(vtype=GRB.BINARY, name = "105th_class")
X_106= s_1.addVar(vtype=GRB.BINARY, name = "106th_class")
X_107= s_1.addVar(vtype=GRB.BINARY, name = "107th_class")
X_108= s_1.addVar(vtype=GRB.BINARY, name = "108th_class")
X_109= s_1.addVar(vtype=GRB.BINARY, name = "109th_class")
X_110= s_1.addVar(vtype=GRB.BINARY, name = "110th_class")
X_111= s_1.addVar(vtype=GRB.BINARY, name = "111th_class")
X_112= s_1.addVar(vtype=GRB.BINARY, name = "112th_class")
X_113= s_1.addVar(vtype=GRB.BINARY, name = "113th_class")
X_114= s_1.addVar(vtype=GRB.BINARY, name = "114th_class")
X_115= s_1.addVar(vtype=GRB.BINARY, name = "115th_class")
X_116= s_1.addVar(vtype=GRB.BINARY, name = "116th_class")
X_117= s_1.addVar(vtype=GRB.BINARY, name = "117th_class")
X_118= s_1.addVar(vtype=GRB.BINARY, name = "118th_class")
X_119= s_1.addVar(vtype=GRB.BINARY, name = "119th_class")
X_120= s_1.addVar(vtype=GRB.BINARY, name = "120th_class")
X_121= s_1.addVar(vtype=GRB.BINARY, name = "121th_class")
X_122= s_1.addVar(vtype=GRB.BINARY, name = "122th_class")
X_123= s_1.addVar(vtype=GRB.BINARY, name = "123th_class")
X_124= s_1.addVar(vtype=GRB.BINARY, name = "124th_class")
X_125= s_1.addVar(vtype=GRB.BINARY, name = "125th_class")
X_126= s_1.addVar(vtype=GRB.BINARY, name = "126th_class")
X_127= s_1.addVar(vtype=GRB.BINARY, name = "127th_class")
X_128= s_1.addVar(vtype=GRB.BINARY, name = "128th_class")
X_129= s_1.addVar(vtype=GRB.BINARY, name = "129th_class")
X_130= s_1.addVar(vtype=GRB.BINARY, name = "130th_class")
X_131= s_1.addVar(vtype=GRB.BINARY, name = "131th_class")
X_132= s_1.addVar(vtype=GRB.BINARY, name = "132th_class")
X_133= s_1.addVar(vtype=GRB.BINARY, name = "133th_class")
X_134= s_1.addVar(vtype=GRB.BINARY, name = "134th_class")
X_135= s_1.addVar(vtype=GRB.BINARY, name = "135th_class")
X_136= s_1.addVar(vtype=GRB.BINARY, name = "136th_class")
X_137= s_1.addVar(vtype=GRB.BINARY, name = "137th_class")
X_138= s_1.addVar(vtype=GRB.BINARY, name = "138th_class")
X_139= s_1.addVar(vtype=GRB.BINARY, name = "139th_class")
X_140= s_1.addVar(vtype=GRB.BINARY, name = "140th_class")
X_141= s_1.addVar(vtype=GRB.BINARY, name = "141th_class")
X_142= s_1.addVar(vtype=GRB.BINARY, name = "142th_class")
X_143= s_1.addVar(vtype=GRB.BINARY, name = "143th_class")
X_144= s_1.addVar(vtype=GRB.BINARY, name = "144th_class")
X_145= s_1.addVar(vtype=GRB.BINARY, name = "145th_class")
X_146= s_1.addVar(vtype=GRB.BINARY, name = "146th_class")
X_147= s_1.addVar(vtype=GRB.BINARY, name = "147th_class")
X_148= s_1.addVar(vtype=GRB.BINARY, name = "148th_class")
X_149= s_1.addVar(vtype=GRB.BINARY, name = "149th_class")
X_150= s_1.addVar(vtype=GRB.BINARY, name = "150th_class")
X_151= s_1.addVar(vtype=GRB.BINARY, name = "151th_class")
X_152= s_1.addVar(vtype=GRB.BINARY, name = "152th_class")
X_153= s_1.addVar(vtype=GRB.BINARY, name = "153th_class")
X_154= s_1.addVar(vtype=GRB.BINARY, name = "154th_class")
X_155= s_1.addVar(vtype=GRB.BINARY, name = "155th_class")

# %%
# 요일, 교시 별 강의 수강 여부 변수 

Y_1_1 = s_1.addVar(vtype=GRB.BINARY, name = "day1_period1")
Y_1_2 = s_1.addVar(vtype=GRB.BINARY, name = "day1_period2")
Y_1_3 = s_1.addVar(vtype=GRB.BINARY, name = "day1_period3")
Y_1_4 = s_1.addVar(vtype=GRB.BINARY, name = "day1_period4")
Y_1_5 = s_1.addVar(vtype=GRB.BINARY, name = "day1_period5")
Y_1_6 = s_1.addVar(vtype=GRB.BINARY, name = "day1_period6")
Y_1_7 = s_1.addVar(vtype=GRB.BINARY, name = "day1_period7")
Y_1_8 = s_1.addVar(vtype=GRB.BINARY, name = "day1_period8")
Y_1_9 = s_1.addVar(vtype=GRB.BINARY, name = "day1_period9")
Y_2_1 = s_1.addVar(vtype=GRB.BINARY, name = "day2_period1")
Y_2_2 = s_1.addVar(vtype=GRB.BINARY, name = "day2_period2")
Y_2_3 = s_1.addVar(vtype=GRB.BINARY, name = "day2_period3")
Y_2_4 = s_1.addVar(vtype=GRB.BINARY, name = "day2_period4")
Y_2_5 = s_1.addVar(vtype=GRB.BINARY, name = "day2_period5")
Y_2_6 = s_1.addVar(vtype=GRB.BINARY, name = "day2_period6")
Y_2_7 = s_1.addVar(vtype=GRB.BINARY, name = "day2_period7")
Y_2_8 = s_1.addVar(vtype=GRB.BINARY, name = "day2_period8")
Y_2_9 = s_1.addVar(vtype=GRB.BINARY, name = "day2_period9")
Y_3_1 = s_1.addVar(vtype=GRB.BINARY, name = "day3_period1")
Y_3_2 = s_1.addVar(vtype=GRB.BINARY, name = "day3_period2")
Y_3_3 = s_1.addVar(vtype=GRB.BINARY, name = "day3_period3")
Y_3_4 = s_1.addVar(vtype=GRB.BINARY, name = "day3_period4")
Y_3_5 = s_1.addVar(vtype=GRB.BINARY, name = "day3_period5")
Y_3_6 = s_1.addVar(vtype=GRB.BINARY, name = "day3_period6")
Y_3_7 = s_1.addVar(vtype=GRB.BINARY, name = "day3_period7")
Y_3_8 = s_1.addVar(vtype=GRB.BINARY, name = "day3_period8")
Y_3_9 = s_1.addVar(vtype=GRB.BINARY, name = "day3_period9")
Y_4_1 = s_1.addVar(vtype=GRB.BINARY, name = "day4_period1")
Y_4_2 = s_1.addVar(vtype=GRB.BINARY, name = "day4_period2")
Y_4_3 = s_1.addVar(vtype=GRB.BINARY, name = "day4_period3")
Y_4_4 = s_1.addVar(vtype=GRB.BINARY, name = "day4_period4")
Y_4_5 = s_1.addVar(vtype=GRB.BINARY, name = "day4_period5")
Y_4_6 = s_1.addVar(vtype=GRB.BINARY, name = "day4_period6")
Y_4_7 = s_1.addVar(vtype=GRB.BINARY, name = "day4_period7")
Y_4_8 = s_1.addVar(vtype=GRB.BINARY, name = "day4_period8")
Y_4_9 = s_1.addVar(vtype=GRB.BINARY, name = "day4_period9")
Y_5_1 = s_1.addVar(vtype=GRB.BINARY, name = "day5_period1")
Y_5_2 = s_1.addVar(vtype=GRB.BINARY, name = "day5_period2")
Y_5_3 = s_1.addVar(vtype=GRB.BINARY, name = "day5_period3")
Y_5_4 = s_1.addVar(vtype=GRB.BINARY, name = "day5_period4")
Y_5_5 = s_1.addVar(vtype=GRB.BINARY, name = "day5_period5")
Y_5_6 = s_1.addVar(vtype=GRB.BINARY, name = "day5_period6")
Y_5_7 = s_1.addVar(vtype=GRB.BINARY, name = "day5_period7")
Y_5_8 = s_1.addVar(vtype=GRB.BINARY, name = "day5_period8")
Y_5_9 = s_1.addVar(vtype=GRB.BINARY, name = "day5_period9")

# %%
# 목적함수 입력

s_1.setObjective(4 * X_1 +  4 * X_2 +  3.8 * X_3 +  3.6 * X_4 +  4.4 * X_5 +  4.6 * X_6 
                 +  0 * X_7 +  3.3 * X_8 +  3.5 * X_9 +  4.4 * X_10 +  3.9 * X_11 +  4.4 * X_12 
                 +  4.6 * X_13 +  4.4 * X_14 +  4.7 * X_15 +  4.5 * X_16 +  4.6 * X_17 +  4.7 * X_18 
                 +  4.7 * X_19 +  4.7 * X_20 +  4.8 * X_21 +  4.9 * X_22 +  4.9 * X_23 +  4.7 * X_24 
                 +  4.6 * X_25 +  4.6 * X_26 +  4.9 * X_27 +  4.5 * X_28 +  4.8 * X_29 +  4.7 * X_30 
                 +  4.8 * X_31 +  4.4 * X_32 +  4.5 * X_33 +  4.9 * X_34 +  3.5 * X_35 +  4.1 * X_36 
                 +  4.6 * X_37 +  4.7 * X_38 +  3.9 * X_39 +  0 * X_40 +  4.6 * X_41 +  4.7 * X_42 
                 +  3.6 * X_43 +  4.4 * X_44 +  4.2 * X_45 +  5 * X_46 +  4.9 * X_47 +  4.5 * X_48 
                 +  4.7 * X_49 +  4.4 * X_50 +  4.9 * X_51 +  4 * X_52 +  4 * X_53 +  4.9 * X_54 
                 +  4.9 * X_55 +  4.3 * X_56 +  4.7 * X_57 +  4.6 * X_58 +  4.8 * X_59 +  4.6 * X_60 
                 +  4.4 * X_61 +  4.8 * X_62 +  4.9 * X_63 +  4.8 * X_64 +  4.5 * X_65 +  4.7 * X_66 
                 +  4.9 * X_67 +  4.8 * X_68 +  4.9 * X_69 +  4.9 * X_70 +  4.8 * X_71 +  4.9 * X_72 
                 +  5 * X_73 +  4.7 * X_74 +  5 * X_75 +  4 * X_76 +  4.1 * X_77 +  4.8 * X_78 
                 +  4.6 * X_79 +  4.9 * X_80 +  5 * X_81 +  4.9 * X_82 +  4.6 * X_83 +  4.3 * X_84 
                 +  4.9 * X_85 +  4.5 * X_86 +  4.5 * X_87 +  4.3 * X_88 +  4.2 * X_89 +  4.3 * X_90 
                 +  4.5 * X_91 +  4.7 * X_92 +  4.7 * X_93 +  4.7 * X_94 +  4.7 * X_95 +  4.6 * X_96 
                 +  4.6 * X_97 +  5 * X_98 +  4.9 * X_99 +  4.6 * X_100 +  4.9 * X_101 +  4.5 * X_102 
                 +  4.6 * X_103 +  3.8 * X_104 +  4.8 * X_105 +  4.7 * X_106 +  4.2 * X_107 +  4.4 * X_108 
                 +  4.5 * X_109 +  4.4 * X_110 +  4.8 * X_111 +  4.4 * X_112 +  4.7 * X_113 +  4.9 * X_114 
                 +  4.9 * X_115 +  4.6 * X_116 +  4.5 * X_117 +  4.3 * X_118 +  4 * X_119 +  4.3 * X_120 
                 +  3.5 * X_121 +  3.7 * X_122 +  4.8 * X_123 +  4.9 * X_124 +  2.7 * X_125 +  4 * X_126 
                 +  3.3 * X_127 +  2.9 * X_128 +  4.8 * X_129 +  4.2 * X_130 +  4.9 * X_131 +  5 * X_132 
                 +  5 * X_133 +  4.5 * X_134 +  4.5 * X_135 +  4.2 * X_136 +  4.6 * X_137 +  3.8 * X_138 
                 +  3.3 * X_139 +  4.1 * X_140 +  3.6 * X_141 +  3.2 * X_142 +  3.6 * X_143 +  3.7 * X_144 
                 +  4.5 * X_145 +  4.2 * X_146 +  4.6 * X_147 +  4.5 * X_148 +  4.5 * X_149 +  4.3 * X_150 
                 +  4.2 * X_151 +  4.5 * X_152 +  4.7 * X_153 +  4 * X_154 +  4.8 * X_155, GRB.MAXIMIZE)

# %% [raw]
# # 공통 제약조건

# %%
# 전공수업 2개 수강

s_1.addConstr(X_1 + X_2 + X_3 + X_4 + X_5 ==2, "2 major classes")
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %%
# 분반 중 1개 선택 가능

#선형대수
s_1.addConstr(X_1 + X_2 <= 1, "one linear algebra")

#미적분학 및 연습 2
s_1.addConstr(X_8 == 1, "one Calculus")

#컴퓨터 언어 및 실습
s_1.addConstr(X_9 == 1, "one Computer Language")

#자유정의진리
s_1.addConstr(X_10 +  X_11 +  X_12 +  X_13 +  X_14 +  X_15 +  X_16 +  X_17 +  X_18 +  X_19 
              +  X_20 +  X_21 +  X_22 +  X_23 +  X_24 +  X_25 +  X_26 +  X_27 +  X_28 +  X_29 
              +  X_30 +  X_31 +  X_32 +  X_33 +  X_34 +  X_35 +  X_36 +  X_37 +  X_38 +  X_39 
              +  X_40 +  X_41 +  X_42 +  X_43 +  X_44 +  X_45 +  X_46 +  X_47 +  X_48 +  X_49 
              +  X_50 +  X_51 +  X_52 +  X_53 +  X_54 +  X_55 +  X_56 +  X_57 +  X_58 +  X_59 
              +  X_60 +  X_61 +  X_62 +  X_63 +  X_64 +  X_65 +  X_66 +  X_67 +  X_68 +  X_69 
              +  X_70 +  X_71 +  X_72 +  X_73 +  X_74 +  X_75 +  X_76 +  X_77 +  X_78 +  X_79 
              +  X_80 +  X_81 +  X_82 +  X_83 +  X_84 +  X_85 +  X_86 +  X_87 +  X_88 +  X_89 
              +  X_90 +  X_91 +  X_92 +  X_93 +  X_94 +  X_95 +  X_96 +  X_97 +  X_98 +  X_99 
              +  X_100 +  X_101 +  X_102 +  X_103 +  X_104 +  X_105 +  X_106 +  X_107 +  X_108 +  X_109 
              +  X_110 +  X_111 +  X_112 +  X_113 +  X_114 +  X_115 +  X_116 +  X_117 +  X_118 +  X_119 
              +  X_120 +  X_121 +  X_122 +  X_123 +  X_124 +  X_125 +  X_126 +  X_127 +  X_128 ==1 , "one LIBERTAS JUSTITIA VERITAS")

#아카데믹 잉글리시
s_1.addConstr(X_129 +  X_130 +  X_131 +  X_132 +  X_133 +  X_134 +  X_135 +  X_136 +  X_137 +  X_138 +  X_139 
              +  X_140 +  X_141 +  X_142 +  X_143 +  X_144 +  X_145 +  X_146 +  X_147 +  X_148 +  X_149 
              +  X_150 +  X_151 +  X_152 +  X_153 +  X_154 +  X_155 == 1, "one Academic English")

#정보적 사고
s_1.addConstr(X_6 == 1 , "one Computational Thinking")

#1학년 세미나
s_1.addConstr(X_7 == 1 , "one Freshmen Seminar")
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %%
# 시간표 매핑 제약조건

#월요일
s_1.addConstr(X_1 <= Y_1_5, "class1 day1 period5")
s_1.addConstr(X_1 <= Y_1_6, "class1 day1 period6")
s_1.addConstr(X_2 <= Y_1_7, "class2 day1 period7")
s_1.addConstr(X_2 <= Y_1_8, "class2 day1 period8")
s_1.addConstr(X_2 <= Y_1_9, "class2 day1 period9")
s_1.addConstr(X_4 <= Y_1_5, "class4 day1 period5")
s_1.addConstr(X_10 <= Y_1_1, "class10 day1 period1")
s_1.addConstr(X_11 <= Y_1_2, "class11 day1 period2")
s_1.addConstr(X_12 <= Y_1_3, "class12 day1 period3")
s_1.addConstr(X_13 <= Y_1_4, "class13 day1 period4")
s_1.addConstr(X_14 <= Y_1_5, "class14 day1 period5")
s_1.addConstr(X_15 <= Y_1_6, "class15 day1 period6")
s_1.addConstr(X_22 <= Y_1_1, "class22 day1 period1")
s_1.addConstr(X_23 <= Y_1_2, "class23 day1 period2")
s_1.addConstr(X_24 <= Y_1_3, "class24 day1 period3")
s_1.addConstr(X_25 <= Y_1_4, "class25 day1 period4")
s_1.addConstr(X_26 <= Y_1_5, "class26 day1 period5")
s_1.addConstr(X_27 <= Y_1_6, "class27 day1 period6")
s_1.addConstr(X_34 <= Y_1_1, "class34 day1 period1")
s_1.addConstr(X_35 <= Y_1_2, "class35 day1 period2")
s_1.addConstr(X_36 <= Y_1_3, "class36 day1 period3")
s_1.addConstr(X_37 <= Y_1_4, "class37 day1 period4")
s_1.addConstr(X_38 <= Y_1_5, "class38 day1 period5")
s_1.addConstr(X_39 <= Y_1_6, "class39 day1 period6")
s_1.addConstr(X_46 <= Y_1_1, "class46 day1 period1")
s_1.addConstr(X_47 <= Y_1_2, "class47 day1 period2")
s_1.addConstr(X_48 <= Y_1_3, "class48 day1 period3")
s_1.addConstr(X_49 <= Y_1_4, "class49 day1 period4")
s_1.addConstr(X_50 <= Y_1_5, "class50 day1 period5")
s_1.addConstr(X_51 <= Y_1_6, "class51 day1 period6")
s_1.addConstr(X_58 <= Y_1_1, "class58 day1 period1")
s_1.addConstr(X_59 <= Y_1_2, "class59 day1 period2")
s_1.addConstr(X_60 <= Y_1_3, "class60 day1 period3")
s_1.addConstr(X_61 <= Y_1_4, "class61 day1 period4")
s_1.addConstr(X_62 <= Y_1_5, "class62 day1 period5")
s_1.addConstr(X_63 <= Y_1_6, "class63 day1 period6")
s_1.addConstr(X_70 <= Y_1_1, "class70 day1 period1")
s_1.addConstr(X_71 <= Y_1_2, "class71 day1 period2")
s_1.addConstr(X_72 <= Y_1_3, "class72 day1 period3")
s_1.addConstr(X_73 <= Y_1_4, "class73 day1 period4")
s_1.addConstr(X_74 <= Y_1_5, "class74 day1 period5")
s_1.addConstr(X_75 <= Y_1_6, "class75 day1 period6")
s_1.addConstr(X_82 <= Y_1_1, "class82 day1 period1")
s_1.addConstr(X_83 <= Y_1_2, "class83 day1 period2")
s_1.addConstr(X_84 <= Y_1_3, "class84 day1 period3")
s_1.addConstr(X_85 <= Y_1_4, "class85 day1 period4")
s_1.addConstr(X_86 <= Y_1_5, "class86 day1 period5")
s_1.addConstr(X_87 <= Y_1_6, "class87 day1 period6")
s_1.addConstr(X_94 <= Y_1_1, "class94 day1 period1")
s_1.addConstr(X_95 <= Y_1_2, "class95 day1 period2")
s_1.addConstr(X_96 <= Y_1_3, "class96 day1 period3")
s_1.addConstr(X_97 <= Y_1_4, "class97 day1 period4")
s_1.addConstr(X_98 <= Y_1_5, "class98 day1 period5")
s_1.addConstr(X_99 <= Y_1_6, "class99 day1 period6")
s_1.addConstr(X_105 <= Y_1_1, "class105 day1 period1")
s_1.addConstr(X_106 <= Y_1_2, "class106 day1 period2")
s_1.addConstr(X_107 <= Y_1_3, "class107 day1 period3")
s_1.addConstr(X_108 <= Y_1_4, "class108 day1 period4")
s_1.addConstr(X_109 <= Y_1_5, "class109 day1 period5")
s_1.addConstr(X_110 <= Y_1_6, "class110 day1 period6")
s_1.addConstr(X_117 <= Y_1_1, "class117 day1 period1")
s_1.addConstr(X_118 <= Y_1_2, "class118 day1 period2")
s_1.addConstr(X_119 <= Y_1_3, "class119 day1 period3")
s_1.addConstr(X_120 <= Y_1_4, "class120 day1 period4")
s_1.addConstr(X_121 <= Y_1_5, "class121 day1 period5")
s_1.addConstr(X_122 <= Y_1_6, "class122 day1 period6")
s_1.addConstr(X_129 <= Y_1_3, "class129 day1 period3")
s_1.addConstr(X_134 <= Y_1_1, "class134 day1 period1")
s_1.addConstr(X_135 <= Y_1_2, "class135 day1 period2")
s_1.addConstr(X_138 <= Y_1_3, "class138 day1 period3")
s_1.addConstr(X_139 <= Y_1_2, "class139 day1 period2")
s_1.addConstr(X_140 <= Y_1_3, "class140 day1 period3")
s_1.addConstr(X_142 <= Y_1_1, "class142 day1 period1")
s_1.addConstr(X_145 <= Y_1_6, "class145 day1 period6")
s_1.addConstr(X_146 <= Y_1_4, "class146 day1 period4")
s_1.addConstr(X_147 <= Y_1_5, "class147 day1 period5")
s_1.addConstr(X_150 <= Y_1_4, "class150 day1 period4")
s_1.addConstr(X_151 <= Y_1_5, "class151 day1 period5")
s_1.addConstr(X_152 <= Y_1_6, "class152 day1 period6")

#화요일
s_1.addConstr(X_8 <= Y_2_3, "class8 day2 period3")
s_1.addConstr(X_8 <= Y_2_4, "class8 day2 period4")
s_1.addConstr(X_16 <= Y_2_1, "class16 day2 period1")
s_1.addConstr(X_17 <= Y_2_2, "class17 day2 period2")
s_1.addConstr(X_18 <= Y_2_3, "class18 day2 period3")
s_1.addConstr(X_19 <= Y_2_4, "class19 day2 period4")
s_1.addConstr(X_20 <= Y_2_5, "class20 day2 period5")
s_1.addConstr(X_21 <= Y_2_6, "class21 day2 period6")
s_1.addConstr(X_28 <= Y_2_1, "class28 day2 period1")
s_1.addConstr(X_29 <= Y_2_2, "class29 day2 period2")
s_1.addConstr(X_30 <= Y_2_3, "class30 day2 period3")
s_1.addConstr(X_31 <= Y_2_4, "class31 day2 period4")
s_1.addConstr(X_32 <= Y_2_5, "class32 day2 period5")
s_1.addConstr(X_33 <= Y_2_6, "class33 day2 period6")
s_1.addConstr(X_40 <= Y_2_1, "class40 day2 period1")
s_1.addConstr(X_41 <= Y_2_2, "class41 day2 period2")
s_1.addConstr(X_42 <= Y_2_3, "class42 day2 period3")
s_1.addConstr(X_43 <= Y_2_4, "class43 day2 period4")
s_1.addConstr(X_44 <= Y_2_5, "class44 day2 period5")
s_1.addConstr(X_45 <= Y_2_6, "class45 day2 period6")
s_1.addConstr(X_52 <= Y_2_1, "class52 day2 period1")
s_1.addConstr(X_53 <= Y_2_2, "class53 day2 period2")
s_1.addConstr(X_54 <= Y_2_3, "class54 day2 period3")
s_1.addConstr(X_55 <= Y_2_4, "class55 day2 period4")
s_1.addConstr(X_56 <= Y_2_5, "class56 day2 period5")
s_1.addConstr(X_57 <= Y_2_6, "class57 day2 period6")
s_1.addConstr(X_64 <= Y_2_1, "class64 day2 period1")
s_1.addConstr(X_65 <= Y_2_2, "class65 day2 period2")
s_1.addConstr(X_66 <= Y_2_3, "class66 day2 period3")
s_1.addConstr(X_67 <= Y_2_4, "class67 day2 period4")
s_1.addConstr(X_68 <= Y_2_5, "class68 day2 period5")
s_1.addConstr(X_69 <= Y_2_6, "class69 day2 period6")
s_1.addConstr(X_76 <= Y_2_1, "class76 day2 period1")
s_1.addConstr(X_77 <= Y_2_2, "class77 day2 period2")
s_1.addConstr(X_78 <= Y_2_3, "class78 day2 period3")
s_1.addConstr(X_79 <= Y_2_4, "class79 day2 period4")
s_1.addConstr(X_80 <= Y_2_5, "class80 day2 period5")
s_1.addConstr(X_81 <= Y_2_6, "class81 day2 period6")
s_1.addConstr(X_88 <= Y_2_1, "class88 day2 period1")
s_1.addConstr(X_89 <= Y_2_2, "class89 day2 period2")
s_1.addConstr(X_90 <= Y_2_3, "class90 day2 period3")
s_1.addConstr(X_91 <= Y_2_4, "class91 day2 period4")
s_1.addConstr(X_92 <= Y_2_5, "class92 day2 period5")
s_1.addConstr(X_93 <= Y_2_6, "class93 day2 period6")
s_1.addConstr(X_100 <= Y_2_1, "class100 day2 period1")
s_1.addConstr(X_101 <= Y_2_2, "class101 day2 period2")
s_1.addConstr(X_102 <= Y_2_3, "class102 day2 period3")
s_1.addConstr(X_103 <= Y_2_4, "class103 day2 period4")
s_1.addConstr(X_104 <= Y_2_5, "class104 day2 period5")
s_1.addConstr(X_111 <= Y_2_1, "class111 day2 period1")
s_1.addConstr(X_112 <= Y_2_2, "class112 day2 period2")
s_1.addConstr(X_113 <= Y_2_3, "class113 day2 period3")
s_1.addConstr(X_114 <= Y_2_4, "class114 day2 period4")
s_1.addConstr(X_115 <= Y_2_5, "class115 day2 period5")
s_1.addConstr(X_116 <= Y_2_6, "class116 day2 period6")
s_1.addConstr(X_123 <= Y_2_1, "class123 day2 period1")
s_1.addConstr(X_124 <= Y_2_2, "class124 day2 period2")
s_1.addConstr(X_125 <= Y_2_3, "class125 day2 period3")
s_1.addConstr(X_126 <= Y_2_4, "class126 day2 period4")
s_1.addConstr(X_127 <= Y_2_5, "class127 day2 period5")
s_1.addConstr(X_128 <= Y_2_6, "class128 day2 period6")
s_1.addConstr(X_130 <= Y_2_1, "class130 day2 period1")
s_1.addConstr(X_131 <= Y_2_2, "class131 day2 period2")
s_1.addConstr(X_132 <= Y_2_3, "class132 day2 period3")
s_1.addConstr(X_133 <= Y_2_4, "class133 day2 period4")
s_1.addConstr(X_136 <= Y_2_2, "class136 day2 period2")
s_1.addConstr(X_137 <= Y_2_1, "class137 day2 period1")
s_1.addConstr(X_141 <= Y_2_4, "class141 day2 period4")
s_1.addConstr(X_143 <= Y_2_2, "class143 day2 period2")
s_1.addConstr(X_144 <= Y_2_3, "class144 day2 period3")
s_1.addConstr(X_148 <= Y_2_5, "class148 day2 period5")
s_1.addConstr(X_149 <= Y_2_6, "class149 day2 period6")
s_1.addConstr(X_153 <= Y_2_3, "class153 day2 period3")
s_1.addConstr(X_154 <= Y_2_4, "class154 day2 period4")
s_1.addConstr(X_155 <= Y_2_5, "class155 day2 period5")

#수요일
s_1.addConstr(X_4 <= Y_3_5, "class4 day3 period5")
s_1.addConstr(X_10 <= Y_3_1, "class10 day3 period1")
s_1.addConstr(X_11 <= Y_3_2, "class11 day3 period2")
s_1.addConstr(X_12 <= Y_3_3, "class12 day3 period3")
s_1.addConstr(X_13 <= Y_3_4, "class13 day3 period4")
s_1.addConstr(X_14 <= Y_3_5, "class14 day3 period5")
s_1.addConstr(X_15 <= Y_3_6, "class15 day3 period6")
s_1.addConstr(X_22 <= Y_3_1, "class22 day3 period1")
s_1.addConstr(X_23 <= Y_3_2, "class23 day3 period2")
s_1.addConstr(X_24 <= Y_3_3, "class24 day3 period3")
s_1.addConstr(X_25 <= Y_3_4, "class25 day3 period4")
s_1.addConstr(X_26 <= Y_3_5, "class26 day3 period5")
s_1.addConstr(X_27 <= Y_3_6, "class27 day3 period6")
s_1.addConstr(X_34 <= Y_3_1, "class34 day3 period1")
s_1.addConstr(X_35 <= Y_3_2, "class35 day3 period2")
s_1.addConstr(X_36 <= Y_3_3, "class36 day3 period3")
s_1.addConstr(X_37 <= Y_3_4, "class37 day3 period4")
s_1.addConstr(X_38 <= Y_3_5, "class38 day3 period5")
s_1.addConstr(X_39 <= Y_3_6, "class39 day3 period6")
s_1.addConstr(X_46 <= Y_3_1, "class46 day3 period1")
s_1.addConstr(X_47 <= Y_3_2, "class47 day3 period2")
s_1.addConstr(X_48 <= Y_3_3, "class48 day3 period3")
s_1.addConstr(X_49 <= Y_3_4, "class49 day3 period4")
s_1.addConstr(X_50 <= Y_3_5, "class50 day3 period5")
s_1.addConstr(X_51 <= Y_3_6, "class51 day3 period6")
s_1.addConstr(X_58 <= Y_3_1, "class58 day3 period1")
s_1.addConstr(X_59 <= Y_3_2, "class59 day3 period2")
s_1.addConstr(X_60 <= Y_3_3, "class60 day3 period3")
s_1.addConstr(X_61 <= Y_3_4, "class61 day3 period4")
s_1.addConstr(X_62 <= Y_3_5, "class62 day3 period5")
s_1.addConstr(X_63 <= Y_3_6, "class63 day3 period6")
s_1.addConstr(X_70 <= Y_3_1, "class70 day3 period1")
s_1.addConstr(X_71 <= Y_3_2, "class71 day3 period2")
s_1.addConstr(X_72 <= Y_3_3, "class72 day3 period3")
s_1.addConstr(X_73 <= Y_3_4, "class73 day3 period4")
s_1.addConstr(X_74 <= Y_3_5, "class74 day3 period5")
s_1.addConstr(X_75 <= Y_3_6, "class75 day3 period6")
s_1.addConstr(X_82 <= Y_3_1, "class82 day3 period1")
s_1.addConstr(X_83 <= Y_3_2, "class83 day3 period2")
s_1.addConstr(X_84 <= Y_3_3, "class84 day3 period3")
s_1.addConstr(X_85 <= Y_3_4, "class85 day3 period4")
s_1.addConstr(X_86 <= Y_3_5, "class86 day3 period5")
s_1.addConstr(X_87 <= Y_3_6, "class87 day3 period6")
s_1.addConstr(X_94 <= Y_3_1, "class94 day3 period1")
s_1.addConstr(X_95 <= Y_3_2, "class95 day3 period2")
s_1.addConstr(X_96 <= Y_3_3, "class96 day3 period3")
s_1.addConstr(X_97 <= Y_3_4, "class97 day3 period4")
s_1.addConstr(X_98 <= Y_3_5, "class98 day3 period5")
s_1.addConstr(X_99 <= Y_3_6, "class99 day3 period6")
s_1.addConstr(X_105 <= Y_3_1, "class105 day3 period1")
s_1.addConstr(X_106 <= Y_3_2, "class106 day3 period2")
s_1.addConstr(X_107 <= Y_3_3, "class107 day3 period3")
s_1.addConstr(X_108 <= Y_3_4, "class108 day3 period4")
s_1.addConstr(X_109 <= Y_3_5, "class109 day3 period5")
s_1.addConstr(X_110 <= Y_3_6, "class110 day3 period6")
s_1.addConstr(X_117 <= Y_3_1, "class117 day3 period1")
s_1.addConstr(X_118 <= Y_3_2, "class118 day3 period2")
s_1.addConstr(X_119 <= Y_3_3, "class119 day3 period3")
s_1.addConstr(X_120 <= Y_3_4, "class120 day3 period4")
s_1.addConstr(X_121 <= Y_3_5, "class121 day3 period5")
s_1.addConstr(X_122 <= Y_3_6, "class122 day3 period6")
s_1.addConstr(X_129 <= Y_3_3, "class129 day3 period3")
s_1.addConstr(X_134 <= Y_3_1, "class134 day3 period1")
s_1.addConstr(X_135 <= Y_3_2, "class135 day3 period2")
s_1.addConstr(X_138 <= Y_3_3, "class138 day3 period3")
s_1.addConstr(X_139 <= Y_3_2, "class139 day3 period2")
s_1.addConstr(X_140 <= Y_3_3, "class140 day3 period3")
s_1.addConstr(X_142 <= Y_3_1, "class142 day3 period1")
s_1.addConstr(X_145 <= Y_3_6, "class145 day3 period6")
s_1.addConstr(X_146 <= Y_3_4, "class146 day3 period4")
s_1.addConstr(X_147 <= Y_3_5, "class147 day3 period5")
s_1.addConstr(X_150 <= Y_3_4, "class150 day3 period4")
s_1.addConstr(X_151 <= Y_3_5, "class151 day3 period5")
s_1.addConstr(X_152 <= Y_3_6, "class152 day3 period6")

#목요일
s_1.addConstr(X_8 <= Y_4_3, "class8 day4 period3")
s_1.addConstr(X_9 <= Y_4_4, "class9 day4 period4")
s_1.addConstr(X_9 <= Y_4_5, "class9 day4 period5")
s_1.addConstr(X_9 <= Y_4_6, "class9 day4 period6")
s_1.addConstr(X_16 <= Y_4_1, "class16 day4 period1")
s_1.addConstr(X_17 <= Y_4_2, "class17 day4 period2")
s_1.addConstr(X_18 <= Y_4_3, "class18 day4 period3")
s_1.addConstr(X_19 <= Y_4_4, "class19 day4 period4")
s_1.addConstr(X_20 <= Y_4_5, "class20 day4 period5")
s_1.addConstr(X_21 <= Y_4_6, "class21 day4 period6")
s_1.addConstr(X_28 <= Y_4_1, "class28 day4 period1")
s_1.addConstr(X_29 <= Y_4_2, "class29 day4 period2")
s_1.addConstr(X_30 <= Y_4_3, "class30 day4 period3")
s_1.addConstr(X_31 <= Y_4_4, "class31 day4 period4")
s_1.addConstr(X_32 <= Y_4_5, "class32 day4 period5")
s_1.addConstr(X_33 <= Y_4_6, "class33 day4 period6")
s_1.addConstr(X_40 <= Y_4_1, "class40 day4 period1")
s_1.addConstr(X_41 <= Y_4_2, "class41 day4 period2")
s_1.addConstr(X_42 <= Y_4_3, "class42 day4 period3")
s_1.addConstr(X_43 <= Y_4_4, "class43 day4 period4")
s_1.addConstr(X_44 <= Y_4_5, "class44 day4 period5")
s_1.addConstr(X_45 <= Y_4_6, "class45 day4 period6")
s_1.addConstr(X_52 <= Y_4_1, "class52 day4 period1")
s_1.addConstr(X_53 <= Y_4_2, "class53 day4 period2")
s_1.addConstr(X_54 <= Y_4_3, "class54 day4 period3")
s_1.addConstr(X_55 <= Y_4_4, "class55 day4 period4")
s_1.addConstr(X_56 <= Y_4_5, "class56 day4 period5")
s_1.addConstr(X_57 <= Y_4_6, "class57 day4 period6")
s_1.addConstr(X_64 <= Y_4_1, "class64 day4 period1")
s_1.addConstr(X_65 <= Y_4_2, "class65 day4 period2")
s_1.addConstr(X_66 <= Y_4_3, "class66 day4 period3")
s_1.addConstr(X_67 <= Y_4_4, "class67 day4 period4")
s_1.addConstr(X_68 <= Y_4_5, "class68 day4 period5")
s_1.addConstr(X_69 <= Y_4_6, "class69 day4 period6")
s_1.addConstr(X_76 <= Y_4_1, "class76 day4 period1")
s_1.addConstr(X_77 <= Y_4_2, "class77 day4 period2")
s_1.addConstr(X_78 <= Y_4_3, "class78 day4 period3")
s_1.addConstr(X_79 <= Y_4_4, "class79 day4 period4")
s_1.addConstr(X_80 <= Y_4_5, "class80 day4 period5")
s_1.addConstr(X_81 <= Y_4_6, "class81 day4 period6")
s_1.addConstr(X_88 <= Y_4_1, "class88 day4 period1")
s_1.addConstr(X_89 <= Y_4_2, "class89 day4 period2")
s_1.addConstr(X_90 <= Y_4_3, "class90 day4 period3")
s_1.addConstr(X_91 <= Y_4_4, "class91 day4 period4")
s_1.addConstr(X_92 <= Y_4_5, "class92 day4 period5")
s_1.addConstr(X_93 <= Y_4_6, "class93 day4 period6")
s_1.addConstr(X_100 <= Y_4_1, "class100 day4 period1")
s_1.addConstr(X_101 <= Y_4_2, "class101 day4 period2")
s_1.addConstr(X_102 <= Y_4_3, "class102 day4 period3")
s_1.addConstr(X_103 <= Y_4_4, "class103 day4 period4")
s_1.addConstr(X_104 <= Y_4_5, "class104 day4 period5")
s_1.addConstr(X_111 <= Y_4_1, "class111 day4 period1")
s_1.addConstr(X_112 <= Y_4_2, "class112 day4 period2")
s_1.addConstr(X_113 <= Y_4_3, "class113 day4 period3")
s_1.addConstr(X_114 <= Y_4_4, "class114 day4 period4")
s_1.addConstr(X_115 <= Y_4_5, "class115 day4 period5")
s_1.addConstr(X_116 <= Y_4_6, "class116 day4 period6")
s_1.addConstr(X_123 <= Y_4_1, "class123 day4 period1")
s_1.addConstr(X_124 <= Y_4_2, "class124 day4 period2")
s_1.addConstr(X_125 <= Y_4_3, "class125 day4 period3")
s_1.addConstr(X_126 <= Y_4_4, "class126 day4 period4")
s_1.addConstr(X_127 <= Y_4_5, "class127 day4 period5")
s_1.addConstr(X_128 <= Y_4_6, "class128 day4 period6")
s_1.addConstr(X_130 <= Y_4_1, "class130 day4 period1")
s_1.addConstr(X_131 <= Y_4_2, "class131 day4 period2")
s_1.addConstr(X_132 <= Y_4_3, "class132 day4 period3")
s_1.addConstr(X_133 <= Y_4_4, "class133 day4 period4")
s_1.addConstr(X_136 <= Y_4_2, "class136 day4 period2")
s_1.addConstr(X_137 <= Y_4_1, "class137 day4 period1")
s_1.addConstr(X_141 <= Y_4_4, "class141 day4 period4")
s_1.addConstr(X_143 <= Y_4_2, "class143 day4 period2")
s_1.addConstr(X_144 <= Y_4_3, "class144 day4 period3")
s_1.addConstr(X_148 <= Y_4_5, "class148 day4 period5")
s_1.addConstr(X_149 <= Y_4_6, "class149 day4 period6")
s_1.addConstr(X_153 <= Y_4_3, "class153 day4 period3")
s_1.addConstr(X_154 <= Y_4_4, "class154 day4 period4")
s_1.addConstr(X_155 <= Y_4_5, "class155 day4 period5")

#금요일
s_1.addConstr(X_3 <= Y_5_1, "class3 day5 period1")
s_1.addConstr(X_3 <= Y_5_2, "class3 day5 period2")
s_1.addConstr(X_5 <= Y_5_5, "class5 day5 period5")
s_1.addConstr(X_5 <= Y_5_6, "class5 day5 period6")
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %%
#각 교시당 1개 수업만 수강

s_1.addConstr(X_10 + X_22 + X_34 + X_46 + X_58 + X_70 + X_82 + X_94 + X_105 + X_117 + X_134 + X_142 <= 1)
s_1.addConstr(X_11 + X_23 + X_35 + X_47 + X_59 + X_71 + X_83 + X_95 + X_106 + X_118 + X_135 + X_139 <= 1)
s_1.addConstr(X_12 + X_24 + X_36 + X_48 + X_60 + X_72 + X_84 + X_96 + X_107 + X_119 + X_129 + X_138 + X_140 <= 1)
s_1.addConstr(X_13 + X_25 + X_37 + X_49 + X_61 + X_73 + X_85 + X_97 + X_108 + X_120 + X_146 + X_150 <= 1)
s_1.addConstr(X_1 + X_4 + X_14 + X_26 + X_38 + X_50 + X_62 + X_74 + X_86 + X_98 + X_109 + X_121 + X_147 + X_151 <= 1)
s_1.addConstr(X_1 + X_15 + X_27 + X_39 + X_51 + X_63 + X_75 + X_87 + X_99 + X_110 + X_122 + X_145 + X_152 <= 1)

s_1.addConstr(X_16 + X_28 + X_40 + X_52 + X_64 + X_76 + X_88 + X_100 + X_111 + X_123 + X_130 + X_137 <= 1)
s_1.addConstr(X_17 + X_29 + X_41 + X_53 + X_65 + X_77 + X_89 + X_101 + X_112 + X_124 + X_131 + X_136 + X_143 <= 1)
s_1.addConstr(X_8 + X_18 + X_30 + X_42 + X_54 + X_66 + X_78 + X_90 + X_102 + X_113 + X_125 + X_132 + X_144 + X_153 <= 1)
s_1.addConstr(X_8 + X_19 + X_31 + X_43 + X_55 + X_67 + X_79 + X_91 + X_103 + X_114 + X_126 + X_133 + X_141 + X_154 <= 1)
s_1.addConstr(X_20 + X_32 + X_44 + X_56 + X_68 + X_80 + X_92 + X_104 + X_115 + X_127 + X_148 + X_155 <= 1)
s_1.addConstr(X_21 + X_33 + X_45 + X_57 + X_69 + X_81 + X_93 + X_116 + X_128 + X_149 <= 1)

s_1.addConstr(X_10 + X_22 + X_34 + X_46 + X_58 + X_70 + X_82 + X_94 + X_105 + X_117 + X_134 + X_142 <= 1)
s_1.addConstr(X_11 + X_23 + X_35 + X_47 + X_59 + X_71 + X_83 + X_95 + X_106 + X_118 + X_135 + X_139 <= 1)
s_1.addConstr(X_12 + X_24 + X_36 + X_48 + X_60 + X_72 + X_84 + X_96 + X_107 + X_119 + X_129 + X_138 + X_140 <= 1)
s_1.addConstr(X_13 + X_25 + X_37 + X_49 + X_61 + X_73 + X_85 + X_97 + X_108 + X_120 + X_146 + X_150 <= 1)
s_1.addConstr(X_4 + X_14 + X_26 + X_38 + X_50 + X_62 + X_74 + X_86 + X_98 + X_109 + X_121 + X_147 + X_151 <= 1)
s_1.addConstr(X_15 + X_27 + X_39 + X_51 + X_63 + X_75 + X_87 + X_99 + X_110 + X_122 + X_145 + X_152 <= 1)

s_1.addConstr(X_16 + X_28 + X_40 + X_52 + X_64 + X_76 + X_88 + X_100 + X_111 + X_123 + X_130 + X_137 <= 1)
s_1.addConstr(X_17 + X_29 + X_41 + X_53 + X_65 + X_77 + X_89 + X_101 + X_112 + X_124 + X_131 + X_136 + X_143 <= 1)
s_1.addConstr(X_8 + X_18 + X_30 + X_42 + X_54 + X_66 + X_78 + X_90 + X_102 + X_113 + X_125 + X_132 + X_144 + X_153 <= 1)
s_1.addConstr(X_9 + X_19 + X_31 + X_43 + X_55 + X_67 + X_79 + X_91 + X_103 + X_114 + X_126 + X_133 + X_141 + X_154 <= 1)
s_1.addConstr(X_9 + X_20 + X_32 + X_44 + X_56 + X_68 + X_80 + X_92 + X_104 + X_115 + X_127 + X_148 + X_155 <= 1)
s_1.addConstr(X_9 + X_21 + X_33 + X_45 + X_57 + X_69 + X_81 + X_93 + X_116 + X_128 + X_149 <= 1)
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %%
# 점심시간 확보

s_1.addConstr(Y_1_3 + Y_1_4 + Y_2_3 + Y_2_4 + Y_3_3 + Y_3_4 + Y_4_3 + Y_4_4 + Y_5_3 + Y_5_4 <=6 , "day1 lunchtime upper bound")
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %% [raw]
# # 개별 제약조건

# %%
# 금요일 공강 필수

s_1.addConstr(Y_5_1 + Y_5_2 + Y_5_3 + Y_5_4 + Y_5_5 + Y_5_6 + Y_5_7 + Y_5_8 + Y_5_9 == 0, "No Class on Friday")
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %%
# 1교시 6교시 3회 이하

s_1.addConstr(Y_1_1 + Y_2_1 + Y_3_1 + Y_4_1 + Y_5_1 <=1, "three first period")
s_1.addConstr(Y_1_6 + Y_2_6 + Y_3_6 + Y_4_6 + Y_5_6 <=1, "three sixth period")
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %%
# 월, 수 11시~ 14시 아르바이트 (수업 수강 불가)

s_1.addConstr(Y_1_2 + Y_1_3 + Y_1_4 + Y_3_2 + Y_3_3 + Y_3_4 ==0 , "monday wednesday part time job")
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %%
# 월, 수 공강 (수업 수강 불가)

s_1.addConstr(Y_1_1 + Y_1_2 + Y_1_3 + Y_1_4 + Y_1_5 + Y_1_6 + Y_1_7 + Y_1_8 + Y_1_9 
              + Y_3_1 + Y_3_2 + Y_3_3 + Y_3_4 + Y_3_5 + Y_3_6 + Y_3_7 + Y_3_8 + Y_3_9 ==0 , "monday wednesday part time job")
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %%
# 오전 수업 수강 불가

s_1.addConstr(Y_1_1 + Y_1_2 + Y_2_1 + Y_2_2 + Y_3_1 + Y_3_2 + Y_4_1 + Y_4_2 + Y_5_1 + Y_5_2 == 0)
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %%
s_1.optimize()
# Out:
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: Intel(R) Core(TM) i3-8145U CPU @ 2.10GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 343 rows, 200 columns and 1097 nonzeros
# Model fingerprint: 0x72330853
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e+00, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R342 by 10.000000000
#
# Found heuristic solution: objective 28.9000000
# Presolve removed 338 rows and 194 columns
# Presolve time: 0.00s
# Presolved: 5 rows, 6 columns, 12 nonzeros
# Found heuristic solution: objective 29.6000000
# Variable types: 0 continuous, 6 integer (6 binary)
#
# ...

# %%
print(f"최대 평점: {s_1.objVal}")
for v in s_1.getVars(): 
    print(f"{v.varName}:{v.x}")
# Out:
# 최대 평점: 29.600000000000005
# 1th_class:0.0
# 2th_class:1.0
# 3th_class:0.0
# 4th_class:0.0
# 5th_class:1.0
# 6th_class:1.0
# 7th_class:1.0
# 8th_class:1.0
# 9th_class:1.0
# 10th_class:0.0
# 11th_class:0.0
# 12th_class:0.0
# 13th_class:0.0
# 14th_class:0.0
# 15th_class:0.0
# 16th_class:0.0
# 17th_class:0.0
# 18th_class:0.0
# 19th_class:0.0
# 20th_class:0.0
# 21th_class:0.0
# 22th_class:0.0
# 23th_class:0.0
# 24th_class:0.0
# 25th_class:0.0
# 26th_class:0.0
# 27th_class:0.0
# 28th_class:0.0
# 29th_class:0.0
# 30th_class:0.0
# 31th_class:0.0
# 32th_class:0.0
# 33th_class:0.0
# 34th_class:0.0
# 35th_class:0.0
# 36th_class:0.0
# 37th_class:0.0
# 38th_class:0.0
# 39th_class:0.0
# 40th_class:0.0
# 41th_class:0.0
# 42th_class:0.0
# 43th_class:0.0
# 44th_class:0.0
# 45th_class:0.0
# 46th_class:0.0
# 47th_class:0.0
# 48th_class:0.0
# 49th_class:0.0
# 50th_class:0.0
# 51th_class:0.0
# 52th_class:0.0
# 53th_class:0.0
# 54th_class:0.0
# 55th_class:0.0
# 56th_class:0.0
# 57th_class:0.0
# ...
